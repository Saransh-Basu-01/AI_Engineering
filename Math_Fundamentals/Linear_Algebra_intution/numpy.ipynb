# %% [markdown]
# # with Numpy

# %%
import numpy as np

a = np.array([1, 2, 3], dtype=float)
b = np.array([4, 5, 6], dtype=float)

print(f"a + b = {a + b}")
print(f"a · b = {np.dot(a, b)}")
print(f"|a| = {np.linalg.norm(a):.4f}")
print(f"cosine = {np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b)):.4f}")

W = np.random.randn(2, 3) * 0.1
x = np.array([1.0, 0.5, -0.3])
print(f"Wx = {W @ x}")
# Out:
# a + b = [5. 7. 9.]
# a · b = 32.0
# |a| = 3.7417
# cosine = 0.9746
# Wx = [-0.01895274  0.26213992]

# %% [markdown]
# # Rank, Projection, and QR with NumPy

# %%
import numpy as np

A = np.array([[1, 2], [2, 4]])
print(f"Rank: {np.linalg.matrix_rank(A)}")

a = np.array([3, 4])
b = np.array([1, 0])
proj = (np.dot(a, b) / np.dot(b, b)) * b
print(f"Projection of {a} onto {b}: {proj}")

Q, R = np.linalg.qr(np.random.randn(3, 3))
print(f"Q is orthogonal: {np.allclose(Q @ Q.T, np.eye(3))}")
print(f"R is upper triangular: {np.allclose(R, np.triu(R))}")
# Out:
# Rank: 1
# Projection of [3 4] onto [1 0]: [3. 0.]
# Q is orthogonal: True
# R is upper triangular: True

# %% [markdown]
# ## The np.allclose() Function Explained
# - Purpose: Checks if two arrays are approximately equal (allows small floating-point errors).

# %% [markdown]
# # PyTorch -- Tensors Are Vectors with Autodiff

# %%
import torch

x = torch.randn(3, requires_grad=True)
y = torch.tensor([1.0, 0.0, 0.0])

similarity = torch.dot(x, y)
similarity.backward()

print(f"x = {x.data}")
print(f"y = {y.data}")
print(f"dot product = {similarity.item():.4f}")
print(f"d(dot)/dx = {x.grad}")
# Out:
# x = tensor([ 1.6441, -0.3605, -1.0512])
# y = tensor([1., 0., 0.])
# dot product = 1.6441
# d(dot)/dx = tensor([1., 0., 0.])
