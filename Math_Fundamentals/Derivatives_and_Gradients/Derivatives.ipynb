# %% [markdown]
# Numerical Derivative from the scratch

# %%
def numerical_derivative(f, x, h=1e-7):
    return (f(x + h) - f(x - h)) / (2 * h)

def f(x):
    return x ** 2

for x in [-2, -1, 0, 1, 2]:
    numerical = numerical_derivative(f, x)
    analytical = 2 * x
    print(f"x={x:2d}  f'(x) numerical={numerical:.6f}  analytical={analytical:.1f}")
# Out:
# x=-2  f'(x) numerical=-4.000000  analytical=-4.0
# x=-1  f'(x) numerical=-2.000000  analytical=-2.0
# x= 0  f'(x) numerical=0.000000  analytical=0.0
# x= 1  f'(x) numerical=2.000000  analytical=2.0
# x= 2  f'(x) numerical=4.000000  analytical=4.0

# %% [markdown]
# Partial Derivatives and Gradients

# %%
def numerical_gradient(f, point, h=1e-7):
    gradient = []
    for i in range(len(point)):
        point_plus = list(point)
        point_minus = list(point)
        point_plus[i] += h
        point_minus[i] -= h
        partial = (f(point_plus) - f(point_minus)) / (2 * h)
        gradient.append(partial)
    return gradient

def f_multi(point):
    x, y = point
    return x**2 + 3*x*y + y**2

grad = numerical_gradient(f_multi, [1.0, 2.0])
print(f"Numerical gradient at (1,2): {[f'{g:.4f}' for g in grad]}")
print(f"Analytical gradient at (1,2): [2*1+3*2, 3*1+2*2] = [{2*1+3*2}, {3*1+2*2}]")
# Out:
# Numerical gradient at (1,2): ['8.0000', '7.0000']
# Analytical gradient at (1,2): [2*1+3*2, 3*1+2*2] = [8, 7]

# %% [markdown]
# ### Why Bother With Numerical Gradient?
# You often can't (or don't want to) derive the analytical gradient by hand:
#
# - Neural networks have millions of parameters — writing the analytical derivative is infeasible.
#
# - Debugging: You compute both numerical and analytical gradients. If they disagree, your backprop / analytical code has a bug. This is called a gradient check — a very common trick in deep learning.
#
# - Sanity check: Numerical gradient is slow but always works, so it's the "ground truth" test.

# %% [markdown]
# Gradient descent to find the minimum of f(x) = x^2

# %%
x=5.0
lr=0.1
for step in range(20):
    grad=2*x
    x=x-lr*grad
    print(f"step {step:2d}  x={x:8.4f}  f(x)={x**2:10.6f}")
# Out:
# step  0  x=  4.0000  f(x)= 16.000000
# step  1  x=  3.2000  f(x)= 10.240000
# step  2  x=  2.5600  f(x)=  6.553600
# step  3  x=  2.0480  f(x)=  4.194304
# step  4  x=  1.6384  f(x)=  2.684355
# step  5  x=  1.3107  f(x)=  1.717987
# step  6  x=  1.0486  f(x)=  1.099512
# step  7  x=  0.8389  f(x)=  0.703687
# step  8  x=  0.6711  f(x)=  0.450360
# step  9  x=  0.5369  f(x)=  0.288230
# step 10  x=  0.4295  f(x)=  0.184467
# step 11  x=  0.3436  f(x)=  0.118059
# step 12  x=  0.2749  f(x)=  0.075558
# step 13  x=  0.2199  f(x)=  0.048357
# step 14  x=  0.1759  f(x)=  0.030949
# step 15  x=  0.1407  f(x)=  0.019807
# step 16  x=  0.1126  f(x)=  0.012677
# step 17  x=  0.0901  f(x)=  0.008113
# step 18  x=  0.0721  f(x)=  0.005192
# step 19  x=  0.0576  f(x)=  0.003323

# %% [markdown]
# Gradient descent on a 2D function

# %%
def f_2d(point):
    x,y=point
    return x**2 +y**2

point=[4.0,3.0]
lr=0.1
for step in range(20):
    grad=numerical_gradient(f_2d,point)
    point=[p-lr*g for p,g in zip(point,grad)]
    # print(point)
    loss = f_2d(point)
    if step % 5 == 0 or step == 29:
        print(f"step {step:2d}  point=({point[0]:7.4f}, {point[1]:7.4f})  f={loss:.6f}")
# Out:
# step  0  point=( 3.2000,  2.4000)  f=16.000000
# step  5  point=( 1.0486,  0.7864)  f=1.717987
# step 10  point=( 0.3436,  0.2577)  f=0.184467
# step 15  point=( 0.1126,  0.0844)  f=0.019807

# %% [markdown]
# Comparing numerical and analytical derivatives

# %%
import math 
test_functions=[
    ("x^2",    lambda x:x**2,    lambda x:2*x),
       ("x^3",      lambda x: x**3,          lambda x: 3*x**2),
    ("sin(x)",   lambda x: math.sin(x),   lambda x: math.cos(x)),
    ("e^x",      lambda x: math.exp(x),   lambda x: math.exp(x)),
    ("1/x",      lambda x: 1/x,           lambda x: -1/x**2),
]

x=2.0
print(f"{'Function':<12} {'Numerical':>12} {'Analytical':>12} {'Error':>12}")
print("-" * 50)

for name,f,df in test_functions:
    num=numerical_derivative(f,x)
    ana=df(x)
    err=abs(num-ana)
    print(f"{name:<12} {num:12.6f} {ana:12.6f} {err:12.2e}")
# Out:
# Function        Numerical   Analytical        Error
# --------------------------------------------------
# x^2              4.000000     4.000000     4.33e-09
# x^3             12.000000    12.000000     6.32e-09
# sin(x)          -0.416147    -0.416147     1.12e-10
# e^x              7.389056     7.389056     7.50e-09
# 1/x             -0.250000    -0.250000     1.32e-10

# %% [markdown]
# Computing the Hessian numerically

# %%
def hessian_2d(f, x, y, h=1e-5):
    fxx = (f(x + h, y) - 2 * f(x, y) + f(x - h, y)) / (h ** 2)
    fyy = (f(x, y + h) - 2 * f(x, y) + f(x, y - h)) / (h ** 2)
    fxy = (f(x + h, y + h) - f(x + h, y - h) - f(x - h, y + h) + f(x - h, y - h)) / (4 * h ** 2)
    return [[fxx, fxy], [fxy, fyy]]

def saddle(x, y):
    return x ** 2 - y ** 2

def bowl(x, y):
    return x ** 2 + y ** 2

H_saddle = hessian_2d(saddle, 0.0, 0.0)
H_bowl = hessian_2d(bowl, 0.0, 0.0)
print(f"Saddle Hessian: {H_saddle}") 
print(f"Bowl Hessian:   {H_bowl}")
# Out:
# Saddle Hessian: [[2.0, 0.0], [0.0, -2.0]]
# Bowl Hessian:   [[2.0, 0.0], [0.0, 2.0]]

# %% [markdown]
#  Taylor approximation in action

# %%
import math

def taylor_approx(f, f_prime, f_double_prime, x0, h, order=2):
    result = f(x0)
    if order >= 1:
        result += f_prime(x0) * h
    if order >= 2:
        result += 0.5 * f_double_prime(x0) * h ** 2
    return result

x0 = 0.0
for h in [0.1, 0.5, 1.0, 2.0]:
    true_val = math.sin(h)
    t1 = taylor_approx(math.sin, math.cos, lambda x: -math.sin(x), x0, h, order=1)
    t2 = taylor_approx(math.sin, math.cos, lambda x: -math.sin(x), x0, h, order=2)
    print(f"h={h:.1f}  sin(h)={true_val:.4f}  order1={t1:.4f}  order2={t2:.4f}")
# Out:
# h=0.1  sin(h)=0.0998  order1=0.1000  order2=0.1000
# h=0.5  sin(h)=0.4794  order1=0.5000  order2=0.5000
# h=1.0  sin(h)=0.8415  order1=1.0000  order2=1.0000
# h=2.0  sin(h)=0.9093  order1=2.0000  order2=2.0000
